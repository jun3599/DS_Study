# %%
from text_manager import * 
from text_analyzer_ver2 import * 
import pandas as pd

# %%
df = pd.read_excel('C:\\Users\\wnsgn\\Desktop\\pro_git\\data_science_study\\DS_Study\\result.xlsx')
df
# Out:
#                                        title            input_date  \
# 0              '검찰총장 윤석열' 그림자에 與野 진영갈등 폭발 조짐   2022.02.10. 오후 5:33
# 1        "최악들만 모인 선거"… 책 출간한 김종인, 李·尹 싸잡아 비판   2022.02.10. 오후 5:32
# 2    尹 “세금으로 편 가르지 않겠다…세금이 아깝지 않은 유능한 정부될 것”   2022.02.10. 오후 5:31
# 3          김병준 "이재명과 안철수 단일화는 상식적으로 이해가 안 돼"   2022.02.10. 오후 5:31
# 4          李"삼성으로부터 상생 배워" 尹 "세금으로 편가르기 않겠다"   2022.02.10. 오후 5:30
# ..                                       ...                   ...
# 629                           인사말 마친 문재인 대통령  2022.02.10. 오후 12:37
# 630                           인사말 마친 문재인 대통령  2022.02.10. 오후 12:37
# 631                           인사말 마친 문재인 대통령  2022.02.10. 오후 12:37
# 632             자립준비청년 초청 오찬 간담회 참석한 문재인 대통령  2022.02.10. 오후 12:36
# 633                       자립준비청년 초청한 문재인 대통령  2022.02.10. 오후 12:35
#
#                                                article
# 0    \n\n\n\n\n'적폐수사' 발언 일파만파…與, 친문 결집 시도 vs 野, 보수층...
# ...

# %%
t = text_Analyzer(df,'title')

# %%
t.visualization_lda_results()
# Out:
# 분석에 포함할 문장의 최소 길이를 재지정 하시겠습니까? (y/n) : y
# 최소 문장의 길이 n을 입력해주세요, 만약 축소를 원치 않으시면 0번을 눌러주세요!2
# C:\Users\wnsgn\anaconda3\lib\site-packages\numpy\lib\function_base.py:5030: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)
# TF-IDF행렬 생성 완료!: shape=  (634, 1000)
#  self.tfidf 호출시 객체확인 가능
# 그룹화를 진행할 토픽의 수를 입력해주세요: 5
# Topic 1: [('대통령', 30.08948), ('정치', 27.5235), ('윤석열', 27.10028), ('보복', 26.99209), ('적폐', 21.21381), ('발언', 19.80623), ('수사', 19.00906), ('인사말', 18.95528), ('문재인', 18.58666), ('사과', 15.31605)]
# Topic 2: [('선거', 10.36347), ('김종인', 9.78735), ('당선', 8.34535), ('이준석', 7.83659), ('누가', 7.77112), ('사과', 6.19409), ('개입', 6.08085), ('전략', 5.86737), ('최후', 5.63268), ('발언', 5.5944)]
# ...

# %%
topic_df = t.make_main_topic_df()

# %%
topic_df
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# ## gird search cv로 최적 하이퍼 파라미터 찾기

# %%
x1 = ['g','h','j']
x2 = ['a','b','c']

y1 = [1,2,3]
y2 = [2,1,3]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,12))
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.show()

# %%
a = list(map(int, input("입력").split( )))
# Out:
# 입력1 2 3 4 5

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
r = {'a':{'b':1,'c':2}, 't':{'b':1,'c':2}}
import pandas as pd 
pd.DataFrame(r)
# Out:
#    a  t
# b  1  1
# c  2  2
